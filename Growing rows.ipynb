# %%
#Creates rows of ascending numbers (starting from 0), until reaching the input number for '# rows' and '# values in each row'

rows = int(input('Please enter the number of rows: '))
num = 0
for i in range(rows+1):
    for j in range(i):
        print(num, end=' ')
        num+=1
    print('')
